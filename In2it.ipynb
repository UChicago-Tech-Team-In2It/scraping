# %%
import pandas as pd
import numpy as np
from conceptnet5.vectors.query import VectorSpaceWrapper

# %%
all_filenames = ["scrape_community.csv", "vmatch_scrape_advocacy.csv", 
                 "vmatch_scrape_animals.csv","vmatch_scrape_arts_culture.csv","vmatch_scrape_arts_culture.csv",
                 "vmatch_scrape_child_youth.csv","vmatch_scrape_crisis_support.csv","vmatch_scrape_disabilities.csv",
                "vmatch_scrape_edu_lit.csv","vmatch_scrape_health_med.csv","vmatch_scrape_homeless_housing.csv",
                "vmatch_scrape_seniors.csv","vmatch_scrape_women.csv"]
full_name = []
for i in all_filenames:
    full_name.append(("scraping-jerome/{}").format(i))

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in full_name])

# %%
combined_csv
# Out:
#                                                 title  \
# 0    Share your knowledge with a small business owner
# 1   Chicago Court Ordered Community Service VIRTUA...
# 2   Lend your skills to Chicago's arts, cultural, ...
# 3   Volunteer Tax Preparer (no experience necessary!)
# 4                                    Volunteer Mentor
# 5     Share your skills with girls in your community!
# 6                  Inner City Youth Talent Show Staff
# 7          Development School for Youth Support Staff
# 8                      Nonprofit Management Assistant
# 9          Marketing and Hospital Outreach Internship
# 10  Workshop Presenter: Use your knowledge to help...
# 11  Chapter Support Volunteer: Use your skills to ...
# 12  Business Mentor: Share your knowledge with a s...
# 13       Holiday Card Help to Combat Childhood Hunger
# 14  Chicago area Bilingual Home Hospice Patient Su...
# 15          Service Day Afternoon Volunteer- Downtown
# ...

# %%
combined_csv.to_csv( "combined_csv.csv")
